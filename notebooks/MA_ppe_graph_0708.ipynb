# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('MA_ppe_update.csv', index_col='Time', parse_dates=True)
df.head(50)
# Out:
#                                 Region  \
# Time
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29               Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29                  Metro West
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Western Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
# 2020-04-29       Central Massachusetts
#
#                                                        Entity N95s/KN95s  \
# Time
# 2020-04-29                         Nursing home/Senior living     267285
# 2020-04-29                                           Hospital     200000
# 2020-04-29                            Community health center      44550
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...     122634
# 2020-04-29                      Public safety (30-day supply)     167325
# 2020-04-29                                      EMS (Private)      29520
# 2020-04-29                                          Local BOH      10325
# 2020-04-29                                       State agency      44376
# 2020-04-29               Other (e.g. home and pediatric care)     104811
# 2020-04-29                                              Total     990826
# 2020-04-29                         Nursing home/Senior living      72580
# 2020-04-29                                           Hospital      50640
# 2020-04-29                            Community health center       7870
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...      33511
# 2020-04-29                      Public safety (30-day supply)      37800
# 2020-04-29                                      EMS (Private)       2800
# 2020-04-29                                          Local BOH        320
# 2020-04-29                                       State agency        720
# 2020-04-29               Other (e.g. home and pediatric care)      28455
# 2020-04-29                                              Total     234696
# 2020-04-29                         Nursing home/Senior living      64870
# 2020-04-29                                           Hospital      43720
# 2020-04-29                            Community health center      11580
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...      15370
# 2020-04-29                      Public safety (30-day supply)      42785
# 2020-04-29                                      EMS (Private)       7520
# 2020-04-29                                          Local BOH       1320
# 2020-04-29                                       State agency       1420
# 2020-04-29               Other (e.g. home and pediatric care)      23881
# 2020-04-29                                              Total     212466
# 2020-04-29                         Nursing home/Senior living      46860
# 2020-04-29                                           Hospital      26160
# 2020-04-29                            Community health center       5360
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...      18508
# 2020-04-29                      Public safety (30-day supply)      33015
# 2020-04-29                                      EMS (Private)       8880
# 2020-04-29                                          Local BOH       2025
# 2020-04-29                                       State agency          0
# 2020-04-29               Other (e.g. home and pediatric care)      15515
# 2020-04-29                                              Total     156323
# 2020-04-29                         Nursing home/Senior living      34540
# 2020-04-29                                           Hospital      22960
# 2020-04-29                            Community health center       8420
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...      33695
# 2020-04-29                      Public safety (30-day supply)      14450
# 2020-04-29                                      EMS (Private)       3800
# 2020-04-29                                          Local BOH       1340
# 2020-04-29                                       State agency          0
# 2020-04-29               Other (e.g. home and pediatric care)      19145
# 2020-04-29                                              Total     138350
#
#               Masks   Gowns   Gloves Ventilators
# Time
# 2020-04-29   600400   53525   489100           0
# 2020-04-29   165200   21436   104000         675
# 2020-04-29    69750    8013    53400           0
# 2020-04-29   282141  119532  1060650           0
# 2020-04-29        0       0        0           0
# 2020-04-29    18300    1668    34000           0
# 2020-04-29    19500     786    38000           0
# 2020-04-29   166258   31265  1371080           0
# 2020-04-29   541863   49570   837054           0
# 2020-04-29  1863412  285795  3987284         675
# 2020-04-29   128700   17612   169400           0
# 2020-04-29    42400    7370    47000          79
# 2020-04-29     7200     285     2400           0
# 2020-04-29    58005   25942   188320           0
# 2020-04-29        0       0        0           0
# 2020-04-29     2600     186     8000           0
# 2020-04-29     2000      96     6000           0
# 2020-04-29     1400     280     3800           0
# 2020-04-29   166530   14546   261300           0
# 2020-04-29   408835   66317   686220          79
# 2020-04-29   129500   11680    84000           0
# 2020-04-29    27400    4374     2000         136
# 2020-04-29    14350    2154     6000           0
# 2020-04-29    63402   21388   120180           0
# 2020-04-29        0       0        0           0
# 2020-04-29     4600     240        0           0
# 2020-04-29     9500       0     6000           0
# 2020-04-29     1800    1390     1500           0
# 2020-04-29   122860    9384   152500           0
# 2020-04-29   373412   50610   372180         136
# 2020-04-29   112350    9472    67800           0
# 2020-04-29    30700    4004        0          60
# 2020-04-29    10100     990    11000           0
# 2020-04-29    69142   24962   126880           0
# 2020-04-29        0       0        0           0
# 2020-04-29     6900     942    16000           0
# 2020-04-29     2000     300     5000           0
# 2020-04-29        0      50      200           0
# 2020-04-29    69450    9408    97750           0
# 2020-04-29   300642   50128   324630          60
# 2020-04-29    91000    5229    78000           0
# 2020-04-29    11600    1266        0          79
# 2020-04-29    20100    1158    12000           0
# 2020-04-29    43184   26099   201350           0
# 2020-04-29        0       0        0           0
# 2020-04-29     1300     180     5000           0
# 2020-04-29     3000      90     8000           0
# 2020-04-29     2300       0      400           0
# 2020-04-29    91283    9271   149500           0
# 2020-04-29   263767   43293   454250          79

# %% [markdown]
# # Massachusetts

# %%
MA = df[df['Region']=='Massachusetts']
MA
# Out:
#                    Region                                             Entity  \
# Time
# 2020-04-29  Massachusetts                         Nursing home/Senior living
# 2020-04-29  Massachusetts                                           Hospital
# 2020-04-29  Massachusetts                            Community health center
# 2020-04-29  Massachusetts  Local Municipalities (e.g. Fire, Police, Publi...
# 2020-04-29  Massachusetts                      Public safety (30-day supply)
# ...                   ...                                                ...
# 2020-07-08  Massachusetts                                      EMS (Private)
# 2020-07-08  Massachusetts                                          Local BOH
# 2020-07-08  Massachusetts                                       State agency
# 2020-07-08  Massachusetts               Other (e.g. home and pediatric care)
# 2020-07-08  Massachusetts                                              Total
#
#            N95s/KN95s    Masks   Gowns   Gloves Ventilators
# Time
# 2020-04-29     267285   600400   53525   489100           0
# 2020-04-29     200000   165200   21436   104000         675
# 2020-04-29      44550    69750    8013    53400           0
# 2020-04-29     122634   282141  119532  1060650           0
# 2020-04-29     167325        0       0        0           0
# ...               ...      ...     ...      ...         ...
# 2020-07-08      38500    47900    3548    63600           0
# 2020-07-08      16765    53100    1886    80000           0
# 2020-07-08    2644745   969686  122556  3293197           0
# 2020-07-08     325597  1269948  174034  2445342           0
# 2020-07-08    4437140  4041230  691495  8922946         679
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for Massachusetts
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
MA_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    MA_df[index] = MA[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    MA_df[index].plot(ax=axs[index])

# %% [markdown]
# ### The most needed categories for Massachusetts:
# - #### Gloves: 9 million
# - #### N95s/KN95s: 4.5 million
# - #### Masks: 4 million
#
#
# ### Entities with the most PPE distributions:
# - #### N95s/KN95s:
#     - State Agency
#     - Nursing home/Senior living
#     - Local Municipalities (e.g. Fire, Police, Public EMS)
# - #### Masks:
#     - Other
#     - State Agency
#     - Nursing home/Senior living
# - #### Gowns:
#     - Local Municipalities (e.g. Fire, Police, Public EMS)
#     - Other
#     - Nursing home/Senior living
# - #### Gloves:
#     - State agency
#     - Other
#     - Local Municipalities (e.g. Fire, Police, Public EMS)
# - #### Ventilators:
#     - Hospitals
#
# #### Note: Those state agencies which are not linked to specific geographies are tagged as state agencies. The "other" category includes all entities that cannot be classified as one of the 8 entity types.

# %%
# Daily distribution growth of PPE by entities
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
MA_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Daily Distribution Growth of {}'.format(i))
    MA_df[index] = MA[['Entity',i]].pivot(columns='Entity', values=i).astype(float).diff().dropna()
    MA_df[index].plot(ax=axs[index])

# %% [markdown]
# ## Region: ##
# - Western Massachusetts
# - Central Massachusetts
# - Northeastern Massachusetts
# - Metro West
# - Southeastern Massachusetts
# - Metro Boston
#
# <div>
# <img src="attachment:image.png" width="600"/>
# </div>

# %%
Region = df[df['Entity']=='Total']

# %%
# Cumulative distribution of PPE by Regions
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
Region_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    Region_df[index] = Region[['Region',i]].pivot(columns='Region', values=i).astype(float)
    Region_df[index].plot(ax=axs[index])

# %% [markdown]
# ### Regions with the most PPE distributions:
# <div>
# <img align="right" src="attachment:image.png" width="600"/>
# </div>
#
# - #### N95s/KN95s:
#     - State Agency
#     - Metro West
#     - Southeastern Massachusetts
# - #### Masks:
#     - State Agency
#     - Metro West
#     - Southeastern Massachusetts
# - #### Gowns:
#     - Metro West
#     - Southeastern Massachusetts
#     - State Agency
# - #### Gloves:
#     - State agency
#     - Southeastern Massachusetts
#     - Metro West
# - #### Ventilators:
#     - Metro Boston
#     - Metro West
#     - Northeastern Massachusetts

# %%
# Daily distribution growth of PPE by Regions
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
Region_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Daily Distribution Growth of {}'.format(i))
    Region_df[index] = Region[['Region',i]].pivot(columns='Region', values=i).astype(float).diff().dropna()
    Region_df[index].plot(ax=axs[index])

# %% [markdown]
# # Western Massachusetts

# %%
WM = df[df['Region']=='Western Massachusetts']
WM
# Out:
#                            Region  \
# Time
# 2020-04-29  Western Massachusetts
# 2020-04-29  Western Massachusetts
# 2020-04-29  Western Massachusetts
# 2020-04-29  Western Massachusetts
# 2020-04-29  Western Massachusetts
# ...                           ...
# 2020-07-08  Western Massachusetts
# 2020-07-08  Western Massachusetts
# 2020-07-08  Western Massachusetts
# 2020-07-08  Western Massachusetts
# 2020-07-08  Western Massachusetts
#
#                                                        Entity N95s/KN95s  \
# Time
# 2020-04-29                         Nursing home/Senior living      46860
# 2020-04-29                                           Hospital      26160
# 2020-04-29                            Community health center       5360
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...      18508
# 2020-04-29                      Public safety (30-day supply)      33015
# ...                                                       ...        ...
# 2020-07-08                                      EMS (Private)       9400
# 2020-07-08                                          Local BOH       2805
# 2020-07-08                                       State agency        780
# 2020-07-08               Other (e.g. home and pediatric care)      33009
# 2020-07-08                                              Total     276922
#
#              Masks  Gowns  Gloves Ventilators
# Time
# 2020-04-29  112350   9472   67800           0
# 2020-04-29   30700   4004       0          60
# 2020-04-29   10100    990   11000           0
# 2020-04-29   69142  24962  126880           0
# 2020-04-29       0      0       0           0
# ...            ...    ...     ...         ...
# 2020-07-08   14500   1102   32400           0
# 2020-07-08   11600    300    5000           0
# 2020-07-08    4500    350    4400           0
# 2020-07-08  142950  14333  183850           0
# 2020-07-08  515447  87499  547443          60
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for Western Massachusetts
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
WM_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    WM_df[index] = WM[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    WM_df[index].plot(ax=axs[index])

# %% [markdown]
# # Central Massachusetts

# %%
CM = df[df['Region']=='Central Massachusetts']
CM
# Out:
#                            Region  \
# Time
# 2020-04-29  Central Massachusetts
# 2020-04-29  Central Massachusetts
# 2020-04-29  Central Massachusetts
# 2020-04-29  Central Massachusetts
# 2020-04-29  Central Massachusetts
# ...                           ...
# 2020-07-08  Central Massachusetts
# 2020-07-08  Central Massachusetts
# 2020-07-08  Central Massachusetts
# 2020-07-08  Central Massachusetts
# 2020-07-08  Central Massachusetts
#
#                                                        Entity N95s/KN95s  \
# Time
# 2020-04-29                         Nursing home/Senior living      34540
# 2020-04-29                                           Hospital      22960
# 2020-04-29                            Community health center       8420
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...      33695
# 2020-04-29                      Public safety (30-day supply)      14450
# ...                                                       ...        ...
# 2020-07-08                                      EMS (Private)       3800
# 2020-07-08                                          Local BOH       2060
# 2020-07-08                                       State agency       2000
# 2020-07-08               Other (e.g. home and pediatric care)      43729
# 2020-07-08                                              Total     249229
#
#              Masks  Gowns   Gloves Ventilators
# Time
# 2020-04-29   91000   5229    78000           0
# 2020-04-29   11600   1266        0          79
# 2020-04-29   20100   1158    12000           0
# 2020-04-29   43184  26099   201350           0
# 2020-04-29       0      0        0           0
# ...            ...    ...      ...         ...
# 2020-07-08    3300    900     5000           0
# 2020-07-08    9000    490    18000           0
# 2020-07-08    4300    800      400           0
# 2020-07-08  215733  26032   576200           0
# 2020-07-08  474167  90249  1015450          83
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for Central Massachusetts
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
CM_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    CM_df[index] = CM[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    CM_df[index].plot(ax=axs[index])

# %% [markdown]
# # Northeastern Massachusetts

# %%
NM = df[df['Region']=='Northeastern Massachusetts']
NM
# Out:
#                                 Region  \
# Time
# 2020-04-29  Northeastern Massachusetts
# 2020-04-29  Northeastern Massachusetts
# 2020-04-29  Northeastern Massachusetts
# 2020-04-29  Northeastern Massachusetts
# 2020-04-29  Northeastern Massachusetts
# ...                                ...
# 2020-07-08  Northeastern Massachusetts
# 2020-07-08  Northeastern Massachusetts
# 2020-07-08  Northeastern Massachusetts
# 2020-07-08  Northeastern Massachusetts
# 2020-07-08  Northeastern Massachusetts
#
#                                                        Entity N95s/KN95s  \
# Time
# 2020-04-29                         Nursing home/Senior living      33885
# 2020-04-29                                           Hospital      24570
# 2020-04-29                            Community health center       1680
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...       7630
# 2020-04-29                      Public safety (30-day supply)      32820
# ...                                                       ...        ...
# 2020-07-08                                      EMS (Private)       2000
# 2020-07-08                                          Local BOH       2720
# 2020-07-08                                       State agency          0
# 2020-07-08               Other (e.g. home and pediatric care)      35015
# 2020-07-08                                              Total     202526
#
#              Masks  Gowns  Gloves Ventilators
# Time
# 2020-04-29   91900   6766   64200           0
# 2020-04-29   30800   1842    8000         117
# 2020-04-29    3300    396    5000           0
# 2020-04-29   31208   9991  164800           0
# 2020-04-29       0      0       0           0
# ...            ...    ...     ...         ...
# 2020-07-08    6900    120   10200           0
# 2020-07-08    6000     80    9200           0
# 2020-07-08       0    400       0           0
# 2020-07-08  161555  19540  263732           0
# 2020-07-08  392663  51370  731132         117
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for Northeastern Massachusetts
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
NM_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    NM_df[index] = NM[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    NM_df[index].plot(ax=axs[index])

# %% [markdown]
# # Metro West

# %%
MW = df[df['Region']=='Metro West']
MW
# Out:
#                 Region                                             Entity  \
# Time
# 2020-04-29  Metro West                         Nursing home/Senior living
# 2020-04-29  Metro West                                           Hospital
# 2020-04-29  Metro West                            Community health center
# 2020-04-29  Metro West  Local Municipalities (e.g. Fire, Police, Publi...
# 2020-04-29  Metro West                      Public safety (30-day supply)
# ...                ...                                                ...
# 2020-07-08  Metro West                                      EMS (Private)
# 2020-07-08  Metro West                                          Local BOH
# 2020-07-08  Metro West                                       State agency
# 2020-07-08  Metro West               Other (e.g. home and pediatric care)
# 2020-07-08  Metro West                                              Total
#
#            N95s/KN95s   Masks   Gowns   Gloves Ventilators
# Time
# 2020-04-29      64870  129500   11680    84000           0
# 2020-04-29      43720   27400    4374     2000         136
# 2020-04-29      11580   14350    2154     6000           0
# 2020-04-29      15370   63402   21388   120180           0
# 2020-04-29      42785       0       0        0           0
# ...               ...     ...     ...      ...         ...
# 2020-07-08      14440   16600    1240     4000           0
# 2020-07-08       1920   17500     160    14200           0
# 2020-07-08       3643    7000    5190    38500           0
# 2020-07-08     121451  341730   55683   582750           0
# 2020-07-08     518680  737682  160914  1246574         136
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for Metro West
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
MW_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    MW_df[index] = MW[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    MW_df[index].plot(ax=axs[index])

# %% [markdown]
# # Metro Boston

# %%
MB = df[df['Region']=='Metro Boston']
MB
# Out:
#                   Region                                             Entity  \
# Time
# 2020-04-29  Metro Boston                         Nursing home/Senior living
# 2020-04-29  Metro Boston                                           Hospital
# 2020-04-29  Metro Boston                            Community health center
# 2020-04-29  Metro Boston  Local Municipalities (e.g. Fire, Police, Publi...
# 2020-04-29  Metro Boston                      Public safety (30-day supply)
# ...                  ...                                                ...
# 2020-07-08  Metro Boston                                      EMS (Private)
# 2020-07-08  Metro Boston                                          Local BOH
# 2020-07-08  Metro Boston                                       State agency
# 2020-07-08  Metro Boston               Other (e.g. home and pediatric care)
# 2020-07-08  Metro Boston                                              Total
#
#            N95s/KN95s   Masks  Gowns  Gloves Ventilators
# Time
# 2020-04-29      14550   46950   2766   25700           0
# 2020-04-29      31950   22300   2580   47000         204
# 2020-04-29       9640   14700   3030   17000           0
# 2020-04-29      13920   17200  11150  259120           0
# 2020-04-29       6455       0      0       0           0
# ...               ...     ...    ...     ...         ...
# 2020-07-08       5000       0      0       0           0
# 2020-07-08       3720    1000    300    6000           0
# 2020-07-08       1200    1050    668   24400           0
# 2020-07-08      23750   81950  10397  210322           0
# 2020-07-08     168236  259850  49511  716342         204
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for Metro Boston
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
MB_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    MB_df[index] = MB[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    MB_df[index].plot(ax=axs[index])

# %% [markdown]
# # Southeastern Massachusetts

# %%
SM = df[df['Region']=='Southeastern Massachusetts']
SM
# Out:
#                                 Region  \
# Time
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# 2020-04-29  Southeastern Massachusetts
# ...                                ...
# 2020-07-08  Southeastern Massachusetts
# 2020-07-08  Southeastern Massachusetts
# 2020-07-08  Southeastern Massachusetts
# 2020-07-08  Southeastern Massachusetts
# 2020-07-08  Southeastern Massachusetts
#
#                                                        Entity N95s/KN95s  \
# Time
# 2020-04-29                         Nursing home/Senior living      72580
# 2020-04-29                                           Hospital      50640
# 2020-04-29                            Community health center       7870
# 2020-04-29  Local Municipalities (e.g. Fire, Police, Publi...      33511
# 2020-04-29                      Public safety (30-day supply)      37800
# ...                                                       ...        ...
# 2020-07-08                                      EMS (Private)       3860
# 2020-07-08                                          Local BOH       3540
# 2020-07-08                                       State agency       3870
# 2020-07-08               Other (e.g. home and pediatric care)      68643
# 2020-07-08                                              Total     388295
#
#              Masks   Gowns   Gloves Ventilators
# Time
# 2020-04-29  128700   17612   169400           0
# 2020-04-29   42400    7370    47000          79
# 2020-04-29    7200     285     2400           0
# 2020-04-29   58005   25942   188320           0
# 2020-04-29       0       0        0           0
# ...            ...     ...      ...         ...
# 2020-07-08    6600     186    12000           0
# 2020-07-08    8000     556    27600           0
# 2020-07-08    6800    3740    31400           0
# 2020-07-08  324030   47809   628488           0
# 2020-07-08  713385  140304  1471908          79
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for Southeastern Massachusetts
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
SM_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    SM_df[index] = SM[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    SM_df[index].plot(ax=axs[index])

# %% [markdown]
# # State Agency

# %%
SA = df[df['Region']=='State agency']
SA
# Out:
#                   Region                                             Entity  \
# Time
# 2020-04-29  State agency                         Nursing home/Senior living
# 2020-04-29  State agency                                           Hospital
# 2020-04-29  State agency                            Community health center
# 2020-04-29  State agency  Local Municipalities (e.g. Fire, Police, Publi...
# 2020-04-29  State agency                      Public safety (30-day supply)
# ...                  ...                                                ...
# 2020-07-08  State agency                                      EMS (Private)
# 2020-07-08  State agency                                          Local BOH
# 2020-07-08  State agency                                       State agency
# 2020-07-08  State agency               Other (e.g. home and pediatric care)
# 2020-07-08  State agency                                              Total
#
#            N95s/KN95s   Masks   Gowns   Gloves Ventilators
# Time
# 2020-04-29          0       0       0        0           0
# 2020-04-29          0       0       0        0           0
# 2020-04-29          0       0       0        0           0
# 2020-04-29          0       0       0        0           0
# 2020-04-29          0       0       0        0           0
# ...               ...     ...     ...      ...         ...
# 2020-07-08          0       0       0        0           0
# 2020-07-08          0       0       0        0           0
# 2020-07-08    2633252  946036  111408  3194097           0
# 2020-07-08          0    2000     240        0           0
# 2020-07-08    2633252  948036  111648  3194097           0
#
# [350 rows x 7 columns]

# %%
# Cumulative distribution of PPE by entities for State agency
categories = ['N95s/KN95s', 'Masks', 'Gowns', 'Gloves', 'Ventilators']
fig, axs = plt.subplots(5, 1, figsize=(15,50))
SA_df = [pd.DataFrame()]*5
for i in categories:
    index = categories.index(i)
    axs[index].set_ylabel('Number of Units')
    axs[index].set_title('Cumulative Distribution of {}'.format(i))
    SA_df[index] = SA[['Entity',i]].pivot(columns='Entity', values=i).astype(float)
    SA_df[index].plot(ax=axs[index])
